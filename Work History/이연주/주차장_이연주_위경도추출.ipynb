# %% [markdown]
# ## 라이브러리 및 데이터 불러오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(/content/drive/MyDrive/Colab Notebooks/NonSmoking_Project/공유문서/data/06_주차장/전국주차장정보표준데이터.csv", encoding ='cp949')
df
# Out:
#             주차장관리번호           주차장명 주차장구분 주차장유형                 소재지도로명주소  \
# 0      156-2-000043  송현주공시장 공영 주차장    공영    노외       대구광역시 달서구 송현로8안길 6
# 1      156-2-000044  송현2동마을 공영 주차장    공영    노외     대구광역시 달서구 월배로75길 112
# 2      156-2-000045     달비공원 공영주차장    공영    노외        대구광역시 달서구 상화로 420
# 3      156-2-000046     죽전동제2공영주차장    공영    노외        대구광역시 달서구 용산서로 10
# 4      156-2-000047     달서시장 공영주차장    공영    노외      대구광역시 달서구 당산로 37-14
# ...             ...            ...   ...   ...                      ...
# 15310  230-2-000007       북샛말공영주차장    공영    노외       경기도 이천시 이섭대천로 1299
# 15311  230-2-000008      중리천로공영주차장    공영    노외          경기도 이천시 중리천로 38
# 15312  230-2-000009        설봉공원주차장    공영    노외   경기도 이천시 경충대로2709번길 128
# 15313  230-2-000010  백사 산수유꽃축제 주차장    공영    노외  경기도 이천시 백사면 원적로775번길 17
# 15314  230-2-000012    서희청소년 공영주차장    공영    노외          경기도 이천시 영창로 260
#
#                       소재지지번주소  주차구획수 급지구분 부제시행구분        운영요일  ...   월정기권요금  \
# 0       대구광역시 달서구 송현동 1949-21     26    2    미시행  평일+토요일+공휴일  ...  60000.0
# 1         대구광역시 달서구 송현동 496-1     42    3    미시행  평일+토요일+공휴일  ...      NaN
# 2          대구광역시 달서구 상인동 1594     47    3    미시행  평일+토요일+공휴일  ...      NaN
# 3         대구광역시 달서구 용산동 931-5     35    3    미시행  평일+토요일+공휴일  ...      NaN
# 4         대구광역시 달서구 본리동 110-5    103    2    미시행  평일+토요일+공휴일  ...  70000.0
# ...                       ...    ...  ...    ...         ...  ...      ...
# 15310      경기도 이천시 창전동 443-25    129    2    미시행  평일+토요일+공휴일  ...  50000.0
# 15311       경기도 이천시 중리동 180-2     34    1    미시행  평일+토요일+공휴일  ...  60000.0
# 15312         경기도 이천시 관고동 356    431    3    미시행  평일+토요일+공휴일  ...      NaN
# 15313  경기도 이천시 백사면 도립리 1006-1    359    4    미시행  평일+토요일+공휴일  ...      NaN
# 15314         경기도 이천시 창전동 504    200    1    미시행  평일+토요일+공휴일  ...      NaN
#
#           결제방법                                               특기사항       관리기관명  \
# 0           현금  정상금액 기준: 경차60퍼센트할인, 장애인2시간면제 50퍼센트할인, 친환경적, 저공...  대구광역시 달서구청
# 1          NaN                                                NaN  대구광역시 달서구청
# 2          NaN                                                NaN  대구광역시 달서구청
# 3          NaN                                                NaN  대구광역시 달서구청
# 4       현금, 카드  정상금액 기준: 경차60퍼센트할인, 장애인2시간면제 50퍼센트할인, 친환경적, 저공...  대구광역시 달서구청
# ...        ...                                                ...         ...
# 15310  현금+신용카드                                 경차, 장애인 차량 50프로 할인    경기도 이천시청
# 15311  현금+신용카드                                 경차, 장애인 차량 50프로 할인    경기도 이천시청
# 15312      NaN                                                NaN    경기도 이천시청
# 15313      NaN                                                NaN    경기도 이천시청
# 15314      NaN                                                NaN    경기도 이천시청
#
#                전화번호         위도          경도     데이터기준일자   제공기관코드      제공기관명
# 0      053-667-2656  35.822270  128.548959  2021-09-13  3470000  대구광역시 달서구
# 1      053-667-3092  35.832459  128.547577  2021-09-13  3470000  대구광역시 달서구
# 2      053-667-3092  35.807200  128.559447  2021-09-13  3470000  대구광역시 달서구
# 3      053-667-3092  35.857789  128.529562  2021-09-13  3470000  대구광역시 달서구
# 4      053-667-2656  35.841014  128.543167  2021-09-13  3470000  대구광역시 달서구
# ...             ...        ...         ...         ...      ...        ...
# 15310  031-635-2070  37.286151  127.448467  2021-09-03  4070000    경기도 이천시
# 15311  031-635-2070  37.280280  127.442221  2021-09-03  4070000    경기도 이천시
# 15312  031-644-2651  37.279460  127.427557  2021-09-03  4070000    경기도 이천시
# 15313  031-645-3666  37.340781  127.462293  2021-09-03  4070000    경기도 이천시
# 15314  031-635-2070        NaN         NaN  2021-09-03  4070000    경기도 이천시
#
# [15315 rows x 33 columns]

# %%
import requests
import json

# %%
rest_api_key = "33dd50ee8994d447e6960ff61b178b83"

# %%
class KakaoLocalAPI:
    """
    Kakao Local API Controller
    """
    def __init__(self, rest_api_key):
        """
        Rest API key 초기화 및 기능 별 url 설정
        """
        
        # REST API key 설정
        self.rest_api_key = rest_api_key
        self.headers = {"Authorization": "KakaoAK {}".format(rest_api_key)}
        
        # 01 주소검색
        self.URL_01 = "https://dapi.kakao.com/v2/local/search/address.json"
        
    def search_address(self, query, analyze_type = None, page = None, size = None):
        """
        01 주소 검색
        """
        params = {"query": f"{query}"}
    
        if analyze_type != None:
            params["analyze_type"]=f"{analyze_type}"
    
        elif page != None:
            params['page'] = f"{page}"
    
        elif size != None:
            params['size'] = f"{size}"
    
        res = requests.get(self.URL_01, headers = self.headers, params = params)
        document = json.loads(res.text)
    
        return document

# %%
kakao = KakaoLocalAPI(rest_api_key)

# %% [markdown]
# ## 불필요한 컬럼 제거하기

# %%
df1 = df[df['소재지지번주소'].str.contains('대전', na = False)]
df2 = df[df['소재지지번주소'].isnull()]
df3 = df2[df2['소재지도로명주소'].str.contains('대전', na = False)]
df4 = pd.concat([df1,df3], ignore_index=True)
            
df_remove = df4.drop(['주차장관리번호', # 불필요한 데이터
                      '주차장구분', # 불필요한 데이터
                      '주차구획수', # 불필요한 데이터
                      '급지구분', # 불필요한 데이터
                      '부제시행구분', # 불필요한 데이터
                      '운영요일', # 불필요한 데이터
                      '평일운영시작시각', # 불필요한 데이터
                      '평일운영종료시각', # 불필요한 데이터
                      '토요일운영시작시각', # 불필요한 데이터
                      '토요일운영종료시각', # 불필요한 데이터
                      '공휴일운영시작시각', # 불필요한 데이터
                      '공휴일운영종료시각', # 불필요한 데이터
                      '요금정보', # 불필요한 데이터
                      '주차기본시간', # 불필요한 데이터
                      '주차기본요금', # 불필요한 데이터
                      '추가단위시간', # 불필요한 데이터
                      '추가단위요금', # 불필요한 데이터
                      '1일주차권요금적용시간', # 불필요한 데이터
                      '1일주차권요금', # 불필요한 데이터
                      '월정기권요금', # 불필요한 데이터
                      '결제방법', # 불필요한 데이터
                      '특기사항', # 불필요한 데이터
                      '전화번호', # 불필요한 데이터
                      '데이터기준일자', # 불필요한 데이터
                      '관리기관명', # 불필요한 데이터
                      '제공기관코드' # 불필요한 데이터
                      ], axis=1)
                            
df_remove.head()
# Out:
#           주차장명 주차장유형                  소재지도로명주소               소재지지번주소  위도  경도  \
# 0     탄방동탄방역주변    노상       대전광역시 서구 계룡로553번길38       대전광역시 서구 탄방동667 NaN NaN
# 1    유성IC만남의광장    노상  대전광역시 유성구 월드컵대로 31 (장대동)  대전광역시 유성구 장대동 240-43 NaN NaN
# 2  세천7 공한지 주차장    노외                       NaN    대전광역시 동구 세천동 47-11 NaN NaN
# 3  세천8 공한지 주차장    노외                       NaN     대전광역시 동구 세천동 76-1 NaN NaN
# 4     신도시장 주차장    노외         대전광역시 동구 비래서로42번길    대전광역시 동구 가양2동 39-6 NaN NaN
#
#    제공기관명
# 0  대전광역시
# 1  대전광역시
# 2  대전광역시
# 3  대전광역시
# 4  대전광역시

# %%
df_remove
# Out:
#                주차장명 주차장유형                  소재지도로명주소  \
# 0          탄방동탄방역주변    노상       대전광역시 서구 계룡로553번길38
# 1         유성IC만남의광장    노상  대전광역시 유성구 월드컵대로 31 (장대동)
# 2       세천7 공한지 주차장    노외                       NaN
# 3       세천8 공한지 주차장    노외                       NaN
# 4          신도시장 주차장    노외         대전광역시 동구 비래서로42번길
# ..              ...   ...                       ...
# 865        로히트~가을햇살    노상        대전광역시 유성구 농대로2번길 9
# 866        문화2동제2노상    노상      대전광역시 중구 당디로36번길 113
# 867        문화2동제3노상    노상          대전광역시 중구 문화로 170
# 868  어은로58번길(카이스트옆)    노상         대전광역시 유성구 어은로58번길
# 869          이현동주차장    노외  대전광역시 대덕구 대청호수로1326번길 75
#
#                         소재지지번주소         위도          경도      제공기관명
# 0               대전광역시 서구 탄방동667        NaN         NaN      대전광역시
# 1          대전광역시 유성구 장대동 240-43        NaN         NaN      대전광역시
# 2            대전광역시 동구 세천동 47-11        NaN         NaN      대전광역시
# 3             대전광역시 동구 세천동 76-1        NaN         NaN      대전광역시
# 4            대전광역시 동구 가양2동 39-6        NaN         NaN      대전광역시
# ..                          ...        ...         ...        ...
# 865  대전광역시 유성구 어은동 104-17~104-9        NaN         NaN      대전광역시
# 866         대전광역시 중구 문화동 671-10        NaN         NaN      대전광역시
# 867         대전광역시 중구 문화동 374-16        NaN         NaN      대전광역시
# 868                         NaN  36.362589  127.356745  대전광역시 유성구
# 869                         NaN  36.413739  127.466015  대전광역시 대덕구
#
# [870 rows x 7 columns]

# %% [markdown]
# ## 공백 제거하기
# - 엑셀상으로 주소 전후로 입력된 공백 제거.
# - '전라남도 대전면' 주소 행 제거

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/NonSmoking_Project/공유문서/data/06_주차장/주차장_전처리_space.csv', encoding='cp949')
df
# Out:
#                주차장명 주차장유형                  소재지도로명주소  \
# 0          탄방동탄방역주변    노상       대전광역시 서구 계룡로553번길38
# 1         유성IC만남의광장    노상  대전광역시 유성구 월드컵대로 31 (장대동)
# 2       세천7 공한지 주차장    노외                       NaN
# 3       세천8 공한지 주차장    노외                       NaN
# 4          신도시장 주차장    노외         대전광역시 동구 비래서로42번길
# ..              ...   ...                       ...
# 864        로히트~가을햇살    노상        대전광역시 유성구 농대로2번길 9
# 865        문화2동제2노상    노상      대전광역시 중구 당디로36번길 113
# 866        문화2동제3노상    노상          대전광역시 중구 문화로 170
# 867  어은로58번길(카이스트옆)    노상         대전광역시 유성구 어은로58번길
# 868          이현동주차장    노외  대전광역시 대덕구 대청호수로1326번길 75
#
#                         소재지지번주소         위도          경도      제공기관명
# 0               대전광역시 서구 탄방동667        NaN         NaN      대전광역시
# 1          대전광역시 유성구 장대동 240-43        NaN         NaN      대전광역시
# 2            대전광역시 동구 세천동 47-11        NaN         NaN      대전광역시
# 3             대전광역시 동구 세천동 76-1        NaN         NaN      대전광역시
# 4            대전광역시 동구 가양2동 39-6        NaN         NaN      대전광역시
# ..                          ...        ...         ...        ...
# 864  대전광역시 유성구 어은동 104-17~104-9        NaN         NaN      대전광역시
# 865         대전광역시 중구 문화동 671-10        NaN         NaN      대전광역시
# 866         대전광역시 중구 문화동 374-16        NaN         NaN      대전광역시
# 867   대전광역시 유성구 어은동 110 동천빌딩 1층  36.362589  127.356745  대전광역시 유성구
# 868         대전광역시 대덕구 이현동 196-2  36.413739  127.466015  대전광역시 대덕구
#
# [869 rows x 7 columns]

# %% [markdown]
# ## 데이터 전처리
# ### 컬럼명, 순서 변경

# %%
df['구'] = np.nan
df['동'] = np.nan
df.rename(columns = {'소재지도로명주소':'도로명주소', '소재지지번주소':'지번주소'}, inplace=True)
df = df[['주차장명','주차장유형','도로명주소','지번주소','구','동','위도','경도','제공기관명']]
df
# Out:
#                주차장명 주차장유형                     도로명주소  \
# 0          탄방동탄방역주변    노상       대전광역시 서구 계룡로553번길38
# 1         유성IC만남의광장    노상  대전광역시 유성구 월드컵대로 31 (장대동)
# 2       세천7 공한지 주차장    노외                       NaN
# 3       세천8 공한지 주차장    노외                       NaN
# 4          신도시장 주차장    노외         대전광역시 동구 비래서로42번길
# ..              ...   ...                       ...
# 864        로히트~가을햇살    노상        대전광역시 유성구 농대로2번길 9
# 865        문화2동제2노상    노상      대전광역시 중구 당디로36번길 113
# 866        문화2동제3노상    노상          대전광역시 중구 문화로 170
# 867  어은로58번길(카이스트옆)    노상         대전광역시 유성구 어은로58번길
# 868          이현동주차장    노외  대전광역시 대덕구 대청호수로1326번길 75
#
#                            지번주소   구   동         위도          경도      제공기관명
# 0               대전광역시 서구 탄방동667 NaN NaN        NaN         NaN      대전광역시
# 1          대전광역시 유성구 장대동 240-43 NaN NaN        NaN         NaN      대전광역시
# 2            대전광역시 동구 세천동 47-11 NaN NaN        NaN         NaN      대전광역시
# 3             대전광역시 동구 세천동 76-1 NaN NaN        NaN         NaN      대전광역시
# 4            대전광역시 동구 가양2동 39-6 NaN NaN        NaN         NaN      대전광역시
# ..                          ...  ..  ..        ...         ...        ...
# 864  대전광역시 유성구 어은동 104-17~104-9 NaN NaN        NaN         NaN      대전광역시
# 865         대전광역시 중구 문화동 671-10 NaN NaN        NaN         NaN      대전광역시
# 866         대전광역시 중구 문화동 374-16 NaN NaN        NaN         NaN      대전광역시
# 867   대전광역시 유성구 어은동 110 동천빌딩 1층 NaN NaN  36.362589  127.356745  대전광역시 유성구
# 868         대전광역시 대덕구 이현동 196-2 NaN NaN  36.413739  127.466015  대전광역시 대덕구
#
# [869 rows x 9 columns]

# %%
add_list = df['지번주소']
add_list2 = df['도로명주소']

# %% [markdown]
# ### 검색되지 않는 주소 데이터 분리

# %%
df.info()
# 지번주소에 null 이 없으므로 지번주소를 기준으로 위도, 경도 추출
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 869 entries, 0 to 868
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   주차장명    869 non-null    object
#  1   주차장유형   869 non-null    object
#  2   도로명주소   707 non-null    object
#  3   지번주소    869 non-null    object
#  4   구       0 non-null      float64
#  5   동       0 non-null      float64
#  6   위도      488 non-null    float64
#  7   경도      487 non-null    float64
#  8   제공기관명   869 non-null    object
# dtypes: float64(4), object(5)
# memory usage: 61.2+ KB

# %%
# 유효한 주소 데이터의 경우
print(bool(kakao.search_address(add_list[100])['documents']))
print(bool(kakao.search_address(add_list2[100])['documents']))
# Out:
# True
# True

# %%
kakao.search_address(add_list[100])
# Out:
# {'documents': [{'address': {'address_name': '대전 대덕구 송촌동 525',
#     'b_code': '3023010700',
#     'h_code': '3023054300',
#     'main_address_no': '525',
#     'mountain_yn': 'N',
#     'region_1depth_name': '대전',
#     'region_2depth_name': '대덕구',
#     'region_3depth_h_name': '송촌동',
#     'region_3depth_name': '송촌동',
#     'sub_address_no': '',
#     'x': '127.438768548063',
#     'y': '36.3669886660696'},
#    'address_name': '대전 대덕구 송촌동 525',
#    'address_type': 'REGION_ADDR',
#    'road_address': None,
#    'x': '127.438768548063',
#    'y': '36.3669886660696'}],
#  'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}

# %%
# 유효하지 않은 주소 데이터의 경우
print(bool(kakao.search_address(add_list[21])['documents']))
print(bool(kakao.search_address(add_list2[21])['documents']))
# Out:
# False
# False

# %%
error_index = []

for i in range(len(add_list)):
    if (bool(kakao.search_address(add_list[i])['documents']) == False) & (bool(kakao.search_address(add_list2[i])['documents']) == False):
        error_index.append(i)

# %%
len(error_index)
# 검색되지 않는 주소 데이터 22개 존재
# Out:
# 22

# %%
# 주소지 검색 불가한 데이터 별도로 수합 
df_error = pd.DataFrame(columns = {'주차장명', '주차장유형', '도로명주소', '지번주소','위도','경도','제공기관명'})
df_error = df_error[['주차장명', '주차장유형', '도로명주소', '지번주소','위도','경도','제공기관명']]
for i in error_index:
    df_error.loc[i] = df.loc[i]
df_error
# Out:
#                                   주차장명 주차장유형                      도로명주소  \
# 21                           대신동 하상주차장    노외      대전광역시 동구 대동천좌안, 대동천우안
# 23                           소제동 하상주차장    노외      대전광역시 동구 대동천좌안, 대동천우안
# 45                             대사동제6노외    노외        대전광역시 중구 충무로74번길 10
# 48                             산성동제3노외    노외                        NaN
# 50                             석교동제3노외    노외                        NaN
# 66                      대동이스트시티옆 공영주차장    노외                        NaN
# 70                        홍도동 시영아파트 주변    노상  대전광역시 동구 동산1길, 흑정골길, 동산5길
# 125                 자양동 우송대학교 동 캠퍼스 담길    노상           대전광역시 동구 백룡길57번길
# 207                      삼성동 삼성물류센터 주변    노상            대전광역시 동구 현암시장5길
# 210  삼성동 한국아파트 주변(현암로18번길, 태전로174번 안길)    노상          대전광역시 동구 보건소 4,5길
# 215                        신흥삼거리~제1치수교    노상              대전광역시 동구 충무로길
# 217                     용운동 도리어린이공원 주변    노상           대전광역시 동구 새울로23번길
# 220                        가양동 가양천 복개길    노상                        NaN
# 221                        가양동 가양천 복개길    노상                        NaN
# 226                      대동복개도로(대동시장길)    노상             대전광역시 동구 대동복개천
# 227                      대동복개도로(대동시장길)    노상             대전광역시 동구 대동복개천
# 229                    삼성동 건강보험관리공단 주변    노상        대전광역시 동구 현암2,3,4,5길
# 304                            문창동제6노상    노상            대전광역시 중구 남부시장5길
# 375                            석교동제2노외    노외       대전광역시 중구 보문로47번길 144
# 426                             호동제1노상    노상       대전광역시 중구 대종로171번길 49
# 655                           문화1동제7노외    노외                        NaN
# 729                     대동이스트시티옆 공영주차장    노외                        NaN
#
#                                지번주소         위도          경도     제공기관명
# 21                     대전광역시 동구 대동천        NaN         NaN     대전광역시
# 23                     대전광역시 동구 대동천        NaN         NaN     대전광역시
# 45               대전광역시 중구 대사동 129-6  36.316668  127.424859  대전광역시 중구
# 48              대전광역시 중구 산성동 164-15  36.307828   127.38694  대전광역시 중구
# 50               대전광역시 중구 석교동 34-26  36.307248  127.441867  대전광역시 중구
# 66            대전광역시 동구 대동 대동 107-37        NaN         NaN     대전광역시
# 70        대전광역시 동구 동산1길, 흑정골길, 동산5길        NaN         NaN     대전광역시
# 125      대전광역시 동구 자양동 98-17~97-3번지선        NaN         NaN     대전광역시
# 207           대전광역시 동구 삼성동 395번지 주변        NaN         NaN     대전광역시
# 210  대전광역시 동구 삼성동 373, 382,383번지 주변        NaN         NaN     대전광역시
# 215       대전광역시 동구 충무로길(구 신흥동사무소 앞)        NaN         NaN     대전광역시
# 217           대전광역시 동구 용운동 284번지 주변        NaN         NaN     대전광역시
# 220     대전광역시 동구 가양동 아침마을@~가양초교 맞은편        NaN         NaN     대전광역시
# 221    대전광역시 동구 가양동 대전한일신협~영동올갱이해장국        NaN         NaN     대전광역시
# 226         대전광역시 동구 대동복개천(새들뫼@ 앞길)        NaN         NaN     대전광역시
# 227         대전광역시 동구 대동복개천(새들뫼@ 앞길)        NaN         NaN     대전광역시
# 229         대전광역시 동구 삼성동 398-3번지 주변        NaN         NaN     대전광역시
# 304                대전광역시 중구 문창동 381        NaN         NaN     대전광역시
# 375           대전광역시 중구 석교동12-10, 12        NaN         NaN     대전광역시
# 426               대전광역시 중구 호동 247-2        NaN         NaN     대전광역시
# 655               대전광역시 중구 문화동 13-9   36.31485  127.414398  대전광역시 중구
# 729                대전광역시 동구 신흥동 258  36.326966  127.440712  대전광역시 동구

# %%
# 주소지 검색 가능한 데이터만 남김

for i in error_index:
    df = df.drop(index=i, axis=0)
df
# Out:
#                주차장명 주차장유형                     도로명주소  \
# 0          탄방동탄방역주변    노상       대전광역시 서구 계룡로553번길38
# 1         유성IC만남의광장    노상  대전광역시 유성구 월드컵대로 31 (장대동)
# 2       세천7 공한지 주차장    노외                       NaN
# 3       세천8 공한지 주차장    노외                       NaN
# 4          신도시장 주차장    노외         대전광역시 동구 비래서로42번길
# ..              ...   ...                       ...
# 864        로히트~가을햇살    노상        대전광역시 유성구 농대로2번길 9
# 865        문화2동제2노상    노상      대전광역시 중구 당디로36번길 113
# 866        문화2동제3노상    노상          대전광역시 중구 문화로 170
# 867  어은로58번길(카이스트옆)    노상         대전광역시 유성구 어은로58번길
# 868          이현동주차장    노외  대전광역시 대덕구 대청호수로1326번길 75
#
#                            지번주소   구   동         위도          경도      제공기관명
# 0               대전광역시 서구 탄방동667 NaN NaN        NaN         NaN      대전광역시
# 1          대전광역시 유성구 장대동 240-43 NaN NaN        NaN         NaN      대전광역시
# 2            대전광역시 동구 세천동 47-11 NaN NaN        NaN         NaN      대전광역시
# 3             대전광역시 동구 세천동 76-1 NaN NaN        NaN         NaN      대전광역시
# 4            대전광역시 동구 가양2동 39-6 NaN NaN        NaN         NaN      대전광역시
# ..                          ...  ..  ..        ...         ...        ...
# 864  대전광역시 유성구 어은동 104-17~104-9 NaN NaN        NaN         NaN      대전광역시
# 865         대전광역시 중구 문화동 671-10 NaN NaN        NaN         NaN      대전광역시
# 866         대전광역시 중구 문화동 374-16 NaN NaN        NaN         NaN      대전광역시
# 867   대전광역시 유성구 어은동 110 동천빌딩 1층 NaN NaN  36.362589  127.356745  대전광역시 유성구
# 868         대전광역시 대덕구 이현동 196-2 NaN NaN  36.413739  127.466015  대전광역시 대덕구
#
# [847 rows x 9 columns]

# %%
df = df.reset_index(d)

# %%
df.drop(['index'], axis=1)
# Out:
#                주차장명 주차장유형                     도로명주소  \
# 0          탄방동탄방역주변    노상       대전광역시 서구 계룡로553번길38
# 1         유성IC만남의광장    노상  대전광역시 유성구 월드컵대로 31 (장대동)
# 2       세천7 공한지 주차장    노외                       NaN
# 3       세천8 공한지 주차장    노외                       NaN
# 4          신도시장 주차장    노외         대전광역시 동구 비래서로42번길
# ..              ...   ...                       ...
# 842        로히트~가을햇살    노상        대전광역시 유성구 농대로2번길 9
# 843        문화2동제2노상    노상      대전광역시 중구 당디로36번길 113
# 844        문화2동제3노상    노상          대전광역시 중구 문화로 170
# 845  어은로58번길(카이스트옆)    노상         대전광역시 유성구 어은로58번길
# 846          이현동주차장    노외  대전광역시 대덕구 대청호수로1326번길 75
#
#                            지번주소   구   동         위도          경도      제공기관명
# 0               대전광역시 서구 탄방동667 NaN NaN        NaN         NaN      대전광역시
# 1          대전광역시 유성구 장대동 240-43 NaN NaN        NaN         NaN      대전광역시
# 2            대전광역시 동구 세천동 47-11 NaN NaN        NaN         NaN      대전광역시
# 3             대전광역시 동구 세천동 76-1 NaN NaN        NaN         NaN      대전광역시
# 4            대전광역시 동구 가양2동 39-6 NaN NaN        NaN         NaN      대전광역시
# ..                          ...  ..  ..        ...         ...        ...
# 842  대전광역시 유성구 어은동 104-17~104-9 NaN NaN        NaN         NaN      대전광역시
# 843         대전광역시 중구 문화동 671-10 NaN NaN        NaN         NaN      대전광역시
# 844         대전광역시 중구 문화동 374-16 NaN NaN        NaN         NaN      대전광역시
# 845   대전광역시 유성구 어은동 110 동천빌딩 1층 NaN NaN  36.362589  127.356745  대전광역시 유성구
# 846         대전광역시 대덕구 이현동 196-2 NaN NaN  36.413739  127.466015  대전광역시 대덕구
#
# [847 rows x 9 columns]

# %% [markdown]
# ### API를 활용한 구, 동 및 위도 및 경도 추출
# #### 구, 동 추출

# %%
add_list = df['지번주소']
add_list2 = df['도로명주소']

# %%
for i in range(len(add_list)):
    if bool(kakao.search_address(add_list[i])['documents']) == True:
        if bool(kakao.search_address(add_list[i])['documents'][0]['address']) == False:
            print(i)
# Out:
# 200

# %%
kakao.search_address(add_list[200])['documents'][0]['road_address']['region_2depth_name']
# 200번 행의 경우 별도로 추출
# Out:
# '동구'

# %%
for i in range(len(add_list)):     
    if bool(kakao.search_address(add_list2[i])['documents']) == True:    
        if bool(kakao.search_address(add_list2[i])['documents'][0]['road_address']) == False:
            print(i)
# 다음 23개의 행의 경우 별도로 추출
# Out:
# 293
# 294
# 295
# 296
# 308
# 309
# 310
# 311
# 312
# 313
# 314
# 315
# 316
# 320
# 322
# 323
# 324
# 325
# 326
# 375
# 376
# 805
# 808

# %%
kakao.search_address(add_list2[293])['documents'][0]['address']['region_2depth_name']
# Out:
# '유성구'

# %%
for i in range(len(add_list)):     
    if bool(kakao.search_address(add_list[i])['documents']) == True:        
        result_01 = kakao.search_address(add_list[i])
        if bool(result_01['documents'][0]['address']) == False: 
            df['구'][i] = result_01['documents'][0]['road_address']['region_2depth_name'] 
            df['동'][i] = result_01['documents'][0]['road_address']['region_3depth_h_name']
        else:
            addrs_01 = result_01['documents'][0]['address']
            df['구'][i] = addrs_01['region_2depth_name'] 
            df['동'][i] = addrs_01['region_3depth_h_name']
    
    if bool(kakao.search_address(add_list2[i])['documents']) == True:    
        result_02 = kakao.search_address(add_list2[i])    
        if bool(result_02['documents'][0]['road_address']) == False:
            df['구'][i] = result_02['documents'][0]['address']['region_2depth_name'] 
            df['동'][i] = result_02['documents'][0]['address']['region_3depth_h_name']   
        else:
            addrs_02 = result_02['documents'][0]['road_address']
            df['구'][i] = addrs_02['region_2depth_name'] 
            df['동'][i] = addrs_02['region_3depth_h_name']
# Out:
# C:\Users\legra\AppData\Local\Temp\ipykernel_8924\4167834849.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['구'][i] = addrs_02['region_2depth_name']
# C:\Users\legra\AppData\Local\Temp\ipykernel_8924\4167834849.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['동'][i] = addrs_02['region_3depth_name']

# %%
df
# Out:
#      index            주차장명 주차장유형                     도로명주소  \
# 0        0        탄방동탄방역주변    노상       대전광역시 서구 계룡로553번길38
# 1        1       유성IC만남의광장    노상  대전광역시 유성구 월드컵대로 31 (장대동)
# 2        2     세천7 공한지 주차장    노외                       NaN
# 3        3     세천8 공한지 주차장    노외                       NaN
# 4        4        신도시장 주차장    노외         대전광역시 동구 비래서로42번길
# ..     ...             ...   ...                       ...
# 842    864        로히트~가을햇살    노상        대전광역시 유성구 농대로2번길 9
# 843    865        문화2동제2노상    노상      대전광역시 중구 당디로36번길 113
# 844    866        문화2동제3노상    노상          대전광역시 중구 문화로 170
# 845    867  어은로58번길(카이스트옆)    노상         대전광역시 유성구 어은로58번길
# 846    868          이현동주차장    노외  대전광역시 대덕구 대청호수로1326번길 75
#
#                            지번주소    구    동         위도          경도      제공기관명
# 0               대전광역시 서구 탄방동667   서구  탄방동        NaN         NaN      대전광역시
# 1          대전광역시 유성구 장대동 240-43  유성구  장대동        NaN         NaN      대전광역시
# 2            대전광역시 동구 세천동 47-11   동구  세천동        NaN         NaN      대전광역시
# 3             대전광역시 동구 세천동 76-1   동구  세천동        NaN         NaN      대전광역시
# 4            대전광역시 동구 가양2동 39-6   동구  가양동        NaN         NaN      대전광역시
# ..                          ...  ...  ...        ...         ...        ...
# 842  대전광역시 유성구 어은동 104-17~104-9  유성구  어은동        NaN         NaN      대전광역시
# 843         대전광역시 중구 문화동 671-10   중구  문화동        NaN         NaN      대전광역시
# 844         대전광역시 중구 문화동 374-16   중구  문화동        NaN         NaN      대전광역시
# 845   대전광역시 유성구 어은동 110 동천빌딩 1층  유성구  어은동  36.362589  127.356745  대전광역시 유성구
# 846         대전광역시 대덕구 이현동 196-2  대덕구  이현동  36.413739  127.466015  대전광역시 대덕구
#
# [847 rows x 10 columns]

# %% [markdown]
# #### 위도, 경도 추출

# %%
for i in range(len(add_list)):
    if bool(kakao.search_address(add_list[i])) == True:
        result_01 = kakao.search_address(add_list[i])
        if bool(result_01['documents']) == False:
            df['위도'][i] = addrs_02['y']   # 지번주소에 없을 때 도로명주소에서 찾아라
            df['경도'][i] = addrs_02['x']            
        else:
            addrs_01 = result_01['documents'][0]
            df['위도'][i] = addrs_01['y']   # 지번주소에 있다면 지번주소에서 찾아라
            df['경도'][i] = addrs_01['x']
    if bool(kakao.search_address(add_list2[i])) == True:
        result_02 = kakao.search_address(add_list2[i])
        if bool(result_02['documents']) == False: 
            df['위도'][i] = addrs_01['y']   # 도로명주소에 없을 때 지번주소에서 찾아라
            df['경도'][i] = addrs_01['x']           
        else:
            addrs_02 = result_02['documents'][0]
            df['위도'][i] = addrs_02['y']   # 도로명주소에 있다면 도로명주소에서 찾아라
            df['경도'][i] = addrs_02['x']
# Out:
# C:\Users\legra\AppData\Local\Temp\ipykernel_8924\3685451482.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['위도'][i] = addrs_01['y']
# C:\Users\legra\AppData\Local\Temp\ipykernel_8924\3685451482.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['경도'][i] = addrs_01['x']
# C:\Users\legra\AppData\Local\Temp\ipykernel_8924\3685451482.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['위도'][i] = addrs_02['y']
# C:\Users\legra\AppData\Local\Temp\ipykernel_8924\3685451482.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['경도'][i] = addrs_02['x']
# C:\Users\legra\AppData\Local\Temp\ipykernel_8924\3685451482.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['위도'][i] = addrs_01['y']
# C:\Users\legra\AppData\Local\Temp\ipykernel_8924\3685451482.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['경도'][i] = addrs_01['x']
# C:\Users\legra\AppData\Local\Temp\ipykernel_8924\3685451482.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['위도'][i] = addrs_02['y']
# C:\Users\legra\AppData\Local\Temp\ipykernel_8924\3685451482.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['경도'][i] = addrs_02['x']

# %%
df
# Out:
#      index            주차장명 주차장유형                     도로명주소  \
# 0        0        탄방동탄방역주변    노상       대전광역시 서구 계룡로553번길38
# 1        1       유성IC만남의광장    노상  대전광역시 유성구 월드컵대로 31 (장대동)
# 2        2     세천7 공한지 주차장    노외                       NaN
# 3        3     세천8 공한지 주차장    노외                       NaN
# 4        4        신도시장 주차장    노외         대전광역시 동구 비래서로42번길
# ..     ...             ...   ...                       ...
# 842    864        로히트~가을햇살    노상        대전광역시 유성구 농대로2번길 9
# 843    865        문화2동제2노상    노상      대전광역시 중구 당디로36번길 113
# 844    866        문화2동제3노상    노상          대전광역시 중구 문화로 170
# 845    867  어은로58번길(카이스트옆)    노상         대전광역시 유성구 어은로58번길
# 846    868          이현동주차장    노외  대전광역시 대덕구 대청호수로1326번길 75
#
#                            지번주소    구    동                위도                경도  \
# 0               대전광역시 서구 탄방동667   서구  탄방동  36.3446227584109  127.385566564485
# 1          대전광역시 유성구 장대동 240-43  유성구  장대동  36.3634198924993  127.328151931333
# 2            대전광역시 동구 세천동 47-11   동구  세천동  36.3427060298786  127.491031201391
# 3             대전광역시 동구 세천동 76-1   동구  세천동   36.342540618341  127.493252653656
# 4            대전광역시 동구 가양2동 39-6   동구  가양동  36.3509598603544  127.447354961159
# ..                          ...  ...  ...               ...               ...
# 842  대전광역시 유성구 어은동 104-17~104-9  유성구  어은동  36.3611659832176  127.354182995837
# 843         대전광역시 중구 문화동 671-10   중구  문화동  36.3108995023261  127.399076016726
# 844         대전광역시 중구 문화동 374-16   중구  문화동  36.3140745200247  127.404205026795
# 845   대전광역시 유성구 어은동 110 동천빌딩 1층  유성구  어은동  36.3643602204069  127.358314794255
# 846         대전광역시 대덕구 이현동 196-2  대덕구  이현동  36.4137390151827  127.466013361327
#
#          제공기관명
# 0        대전광역시
# 1        대전광역시
# 2        대전광역시
# 3        대전광역시
# 4        대전광역시
# ..         ...
# 842      대전광역시
# 843      대전광역시
# 844      대전광역시
# 845  대전광역시 유성구
# 846  대전광역시 대덕구
#
# [847 rows x 10 columns]

# %%
df = df.drop(['index'], axis=1)
df
# Out:
#                주차장명 주차장유형                     도로명주소  \
# 0          탄방동탄방역주변    노상       대전광역시 서구 계룡로553번길38
# 1         유성IC만남의광장    노상  대전광역시 유성구 월드컵대로 31 (장대동)
# 2       세천7 공한지 주차장    노외                       NaN
# 3       세천8 공한지 주차장    노외                       NaN
# 4          신도시장 주차장    노외         대전광역시 동구 비래서로42번길
# ..              ...   ...                       ...
# 842        로히트~가을햇살    노상        대전광역시 유성구 농대로2번길 9
# 843        문화2동제2노상    노상      대전광역시 중구 당디로36번길 113
# 844        문화2동제3노상    노상          대전광역시 중구 문화로 170
# 845  어은로58번길(카이스트옆)    노상         대전광역시 유성구 어은로58번길
# 846          이현동주차장    노외  대전광역시 대덕구 대청호수로1326번길 75
#
#                            지번주소    구    동                위도                경도  \
# 0               대전광역시 서구 탄방동667   서구  탄방동  36.3446227584109  127.385566564485
# 1          대전광역시 유성구 장대동 240-43  유성구  장대동  36.3634198924993  127.328151931333
# 2            대전광역시 동구 세천동 47-11   동구  세천동  36.3427060298786  127.491031201391
# 3             대전광역시 동구 세천동 76-1   동구  세천동   36.342540618341  127.493252653656
# 4            대전광역시 동구 가양2동 39-6   동구  가양동  36.3509598603544  127.447354961159
# ..                          ...  ...  ...               ...               ...
# 842  대전광역시 유성구 어은동 104-17~104-9  유성구  어은동  36.3611659832176  127.354182995837
# 843         대전광역시 중구 문화동 671-10   중구  문화동  36.3108995023261  127.399076016726
# 844         대전광역시 중구 문화동 374-16   중구  문화동  36.3140745200247  127.404205026795
# 845   대전광역시 유성구 어은동 110 동천빌딩 1층  유성구  어은동  36.3643602204069  127.358314794255
# 846         대전광역시 대덕구 이현동 196-2  대덕구  이현동  36.4137390151827  127.466013361327
#
#          제공기관명
# 0        대전광역시
# 1        대전광역시
# 2        대전광역시
# 3        대전광역시
# 4        대전광역시
# ..         ...
# 842      대전광역시
# 843      대전광역시
# 844      대전광역시
# 845  대전광역시 유성구
# 846  대전광역시 대덕구
#
# [847 rows x 9 columns]

# %% [markdown]
# ## 데이터 저장하기

# %%
# 주소지 검색 가능한 자료
df.to_csv("C://Python//NonSmoking_Project//data//주차장_최종.csv", index=False, encoding='cp949')

# 주소기 검색 불가한 자료
df_error.to_csv("C://Python//NonSmoking_Project//data//주차장_error_최종.csv", index=False, encoding='cp949')
