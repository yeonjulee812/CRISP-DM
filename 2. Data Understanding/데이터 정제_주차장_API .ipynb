# %% [markdown]
# ### Import libraries and data

# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %pwd
# Out:
# 'C:\\Python\\♧SeSAC_Python,R\\000 - 프로젝트\\600.프로젝트\\20.Data Understanding'

# %%
df = pd.read_csv("C:/python/♧SeSAC_Python,R/000 - 프로젝트/600.프로젝트/data/06_주차장/전국주차장정보표준데이터_ansi.csv", encoding ='cp949')
df
# Out:
#             주차장관리번호           주차장명 주차장구분 주차장유형                 소재지도로명주소  \
# 0      156-2-000043  송현주공시장 공영 주차장    공영    노외       대구광역시 달서구 송현로8안길 6
# 1      156-2-000044  송현2동마을 공영 주차장    공영    노외     대구광역시 달서구 월배로75길 112
# 2      156-2-000045     달비공원 공영주차장    공영    노외        대구광역시 달서구 상화로 420
# 3      156-2-000046     죽전동제2공영주차장    공영    노외        대구광역시 달서구 용산서로 10
# 4      156-2-000047     달서시장 공영주차장    공영    노외      대구광역시 달서구 당산로 37-14
# ...             ...            ...   ...   ...                      ...
# 15310  230-2-000007       북샛말공영주차장    공영    노외       경기도 이천시 이섭대천로 1299
# 15311  230-2-000008      중리천로공영주차장    공영    노외          경기도 이천시 중리천로 38
# 15312  230-2-000009        설봉공원주차장    공영    노외   경기도 이천시 경충대로2709번길 128
# 15313  230-2-000010  백사 산수유꽃축제 주차장    공영    노외  경기도 이천시 백사면 원적로775번길 17
# 15314  230-2-000012    서희청소년 공영주차장    공영    노외          경기도 이천시 영창로 260
#
#                       소재지지번주소  주차구획수 급지구분 부제시행구분        운영요일  ...   월정기권요금  \
# ...

# %% [markdown]
# ### basic info on data

# %%
df.describe()
# Out:
#               주차구획수        주차기본시간         주차기본요금   1일주차권요금적용시간        1일주차권요금  \
# count  15315.000000  15315.000000   15315.000000  5.418000e+03    5997.000000
# mean      62.956905     57.082207     399.474763  2.170788e+04    4050.335835
# std      111.564946    422.698806    3001.352574  4.408760e+05    7677.453201
# min        0.000000      0.000000       0.000000  0.000000e+00       0.000000
# 25%       16.000000      0.000000       0.000000  0.000000e+00       0.000000
# 50%       32.000000      0.000000       0.000000  3.500000e+00    2400.000000
# 75%       68.000000     30.000000     400.000000  2.400000e+01    6000.000000
# max     4261.000000  43200.000000  110000.000000  1.000220e+07  150000.000000
#
#               월정기권요금            위도            경도
# count    5601.000000  13037.000000  13034.000000
# mean    41575.204428     36.352779    127.655489
# std     44190.865828      1.121114      0.935662
# min         0.000000     32.573927    124.619641
# ...

# %%
df.info()
# 3.9+MB
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15315 entries, 0 to 15314
# Data columns (total 33 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   주차장관리번호      15315 non-null  object
#  1   주차장명         15315 non-null  object
#  2   주차장구분        15315 non-null  object
#  3   주차장유형        15315 non-null  object
#  4   소재지도로명주소     9354 non-null   object
#  5   소재지지번주소      14400 non-null  object
#  6   주차구획수        15315 non-null  int64
#  7   급지구분         15315 non-null  object
#  8   부제시행구분       15315 non-null  object
#  9   운영요일         15315 non-null  object
#  10  평일운영시작시각     15315 non-null  object
#  11  평일운영종료시각     15315 non-null  object
#  12  토요일운영시작시각    15315 non-null  object
#  13  토요일운영종료시각    15315 non-null  object
#  14  공휴일운영시작시각    15315 non-null  object
#  15  공휴일운영종료시각    15315 non-null  object
#  16  요금정보         15315 non-null  object
#  17  주차기본시간       15315 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['주차장관리번호', '주차장명', '주차장구분', '주차장유형', '소재지도로명주소', '소재지지번주소', '주차구획수',
#        '급지구분', '부제시행구분', '운영요일', '평일운영시작시각', '평일운영종료시각', '토요일운영시작시각',
#        '토요일운영종료시각', '공휴일운영시작시각', '공휴일운영종료시각', '요금정보', '주차기본시간', '주차기본요금',
#        '추가단위시간', '추가단위요금', '1일주차권요금적용시간', '1일주차권요금', '월정기권요금', '결제방법', '특기사항',
#        '관리기관명', '전화번호', '위도', '경도', '데이터기준일자', '제공기관코드', '제공기관명'],
#       dtype='object')

# %% [markdown]
# #### Columns
#
# : * = 지울 수 있는 column
#
# 주차장관리번호*	/ 주차장명 / 주차장구분* / 주차장유형
#
# 소재지도로명주소	/ 소재지지번주소
#
# 주차구획수* /	급지구분 (대중교통과의 거리 등 지역의 편의성)* / 부제시행구분*
#
# 운영요일*	/ 평일운영시작시각*	/ 평일운영종료시각* / 토요일운영시작시각* / 토요일운영종료시각* / 공휴일운영시작시각* / 공휴일운영종료시각*
#
# 요금정보* / 주차기본시간* / 주차기본요금* / 추가단위시간* / 추가단위요금* / 1일주차권* / 요금적용시간* / 1일주차권요금* / 월정기권요금* / 결제방법*
#
# 특기사항* / 관리기관명 / 전화번호* / 위도 / 경도 / 데이터기준일자* / 제공기관코드* / 제공기관명*

# %%
df.dtypes
# Out:
# 주차장관리번호         object
# 주차장명            object
# 주차장구분           object
# 주차장유형           object
# 소재지도로명주소        object
# 소재지지번주소         object
# 주차구획수            int64
# 급지구분            object
# 부제시행구분          object
# 운영요일            object
# 평일운영시작시각        object
# 평일운영종료시각        object
# 토요일운영시작시각       object
# 토요일운영종료시각       object
# 공휴일운영시작시각       object
# 공휴일운영종료시각       object
# 요금정보            object
# 주차기본시간         float64
# 주차기본요금           int64
# 추가단위시간          object
# 추가단위요금          object
# 1일주차권요금적용시간    float64
# 1일주차권요금        float64
# 월정기권요금         float64
# 결제방법            object
# 특기사항            object
# 관리기관명           object
# 전화번호            object
# 위도             float64
# 경도             float64
# 데이터기준일자         object
# 제공기관코드          object
# 제공기관명           object
# dtype: object

# %%
df.isnull().sum()
# unnamed columns는 결측치가 대부분, 어떤 이유로 만들어진 column인지 불분명
# Out:
# 주차장관리번호            0
# 주차장명               0
# 주차장구분              0
# 주차장유형              0
# 소재지도로명주소        5961
# 소재지지번주소          915
# 주차구획수              0
# 급지구분               0
# 부제시행구분             0
# 운영요일               0
# 평일운영시작시각           0
# 평일운영종료시각           0
# 토요일운영시작시각          0
# 토요일운영종료시각          0
# 공휴일운영시작시각          0
# 공휴일운영종료시각          0
# 요금정보               0
# 주차기본시간             0
# 주차기본요금             0
# 추가단위시간          7756
# 추가단위요금          7771
# 1일주차권요금적용시간     9897
# 1일주차권요금         9318
# 월정기권요금          9714
# 결제방법            9847
# 특기사항           11577
# 관리기관명              0
# 전화번호            2318
# 위도              2278
# 경도              2281
# 데이터기준일자            0
# 제공기관코드             0
# 제공기관명              0
# dtype: int64

# %%
list = df['데이터기준일자'].to_list()
list_year = []
for i in list:
    list_year.append(i.split('-')[0])
list_year
# Out:
# ['2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
# ...

# %%
from collections import Counter
Counter(list_year)
# Out:
# Counter({'2021': 12895,
#          '2020': 1529,
#          '2019': 364,
#          '2017': 395,
#          '2018': 131,
#          '2016': 1})

# %%
# 대전 지역만 추출 => '소재지지번주소'
# na = False -> null 값이 존재하면 False 출력
df1 = df[df['소재지지번주소'].str.contains('대전', na = False)]
df1.head()
# Out:
#           주차장관리번호         주차장명 주차장구분 주차장유형                  소재지도로명주소  \
# 20   185-1-000015     탄방동탄방역주변    공영    노상       대전광역시 서구 계룡로553번길38
# 123  186-1-000024    유성IC만남의광장    공영    노상  대전광역시 유성구 월드컵대로 31 (장대동)
# 200  183-2-000013  세천7 공한지 주차장    공영    노외                       NaN
# 201  183-2-000014  세천8 공한지 주차장    공영    노외                       NaN
# 202  183-2-000015     신도시장 주차장    공영    노외         대전광역시 동구 비래서로42번길
#
#                   소재지지번주소  주차구획수 급지구분 부제시행구분        운영요일  ... 월정기권요금  \
# 20        대전광역시 서구 탄방동667     93    1    미시행          평일  ...    NaN
# 123  대전광역시 유성구 장대동 240-43    158    1    미시행  평일+토요일+공휴일  ...    NaN
# 200    대전광역시 동구 세천동 47-11     14    3    미시행  평일+토요일+공휴일  ...    NaN
# 201     대전광역시 동구 세천동 76-1      9    3    미시행  평일+토요일+공휴일  ...    NaN
# 202    대전광역시 동구 가양2동 39-6     30    2    미시행  평일+토요일+공휴일  ...    NaN
#
#          결제방법 특기사항       관리기관명          전화번호  위도  경도     데이터기준일자   제공기관코드  \
# ...

# %%
# '소재지지번주소' = NaN -> '대전' 데이터 추출 후 NaN이 '소재지도로명주소'에 있는것
df2 = df[df['소재지지번주소'].isnull()]
df3 = df2[df2['소재지도로명주소'].str.contains('대전', na = False)]
df3.head()
# Out:
#             주차장관리번호            주차장명 주차장구분 주차장유형                  소재지도로명주소  \
# 2227   186-1-000026  어은로58번길(카이스트옆)    공영    노상         대전광역시 유성구 어은로58번길
# 11222  187-2-000022          이현동주차장    공영    노외  대전광역시 대덕구 대청호수로1326번길 75
#
#       소재지지번주소  주차구획수 급지구분 부제시행구분        운영요일  ... 월정기권요금 결제방법     특기사항  \
# 2227      NaN     14    2    미시행  평일+토요일+공휴일  ...    NaN  NaN      NaN
# 11222     NaN     15   기타    미시행  평일+토요일+공휴일  ...    0.0  NaN  무료공영주차장
#
#             관리기관명          전화번호         위도          경도     데이터기준일자   제공기관코드  \
# 2227   대전광역시 유성구청  042-611-2956  36.362589  127.356745  2021-08-17  3670000
# 11222  대전광역시 대덕구청  042-608-5294  36.413739  127.466015  2020-10-14  3680000
#
#            제공기관명
# 2227   대전광역시 유성구
# 11222  대전광역시 대덕구
#
# [2 rows x 33 columns]

# %%
df4 = pd.concat([df1,df3], ignore_index=True)
df4.shape
# Out:
# (870, 33)

# %% [markdown]
# ### 데이터 정제

# %%
#부제시행구분: 차량 2부제, 5부제 등 = 차량운행을 줄이기 위한 제도
# 시 내의 차량 통행량을 줄이기 위한 제도는 흡연 금지구역과는 무관함
print(df4.shape)
df4 = df4.drop('부제시행구분', axis = 1)
print(df4.shape)
# Out:
# (870, 33)
# (870, 32)

# %%
#추가단위시간: 주차를 기본 시간 이상으로 했을 때, 어떤 단위로 계산하는지
print(df4.shape)
df4 = df4.drop('추가단위시간', axis = 1)
print(df4.shape)
# Out:
# (870, 32)
# (870, 31)

# %%
#추가단위요금: 주차를 기본 시간 이상으로 했을 때, 추가 금액
print(df4.shape)
df4 = df4.drop('추가단위요금', axis = 1)
print(df4.shape)
# Out:
# (870, 31)
# (870, 30)

# %%
#1일주차권요금적용시간: 각 주차장으로 1일 주차권 요금 적용시간
print(df4.shape)
df4 = df4.drop('1일주차권요금적용시간', axis = 1)
print(df4.shape)
# Out:
# (870, 30)
# (870, 29)

# %%
#1일주차권요금: 주차 요금은 흡연과 무관, 더 많은 사람들이 이용할 수 있지만
#               저렴해서 이용량을 증가하고 그 영향이 흡연에도 영향을 미치기 힘듬
print(df4.shape)
df4 = df4.drop('1일주차권요금', axis = 1)
print(df4.shape)
# Out:
# (870, 29)
# (870, 28)

# %%
#월정기권요금
print(df4.shape)
df4 = df4.drop('월정기권요금', axis = 1)
print(df4.shape)
# Out:
# (870, 28)
# (870, 27)

# %%
#결제방법: 흡연과 무관
print(df4.shape)
df4 = df4.drop('결제방법', axis = 1)
print(df4.shape)
# Out:
# (870, 27)
# (870, 26)

# %%
#특기사항: 결측치가 상당히 많아서 전반적 데이터 분석에 도움이 안됨
print(df4.shape)
df4 = df4.drop('특기사항', axis = 1)
print(df4.shape)
# Out:
# (870, 26)
# (870, 25)

# %%
#전화번호
print(df4.shape)
df4 = df4.drop('전화번호', axis = 1)
print(df4.shape)
# Out:
# (870, 25)
# (870, 24)

# %%
#제공기관코드: 데이터를 제공한 기관은 주차장 위치랑 크게 상관이 없음
print(df4.shape)
df4 = df4.drop('제공기관코드', axis = 1)
print(df4.shape)
# Out:
# (870, 24)
# (870, 23)

# %%
df_remove = df4.drop(['주차장관리번호', # 불필요한 데이터
                      '주차장구분', # 불필요한 데이터
                      '주차구획수', # 불필요한 데이터
                      '급지구분', # 불필요한 데이터
                      '운영요일', # 불필요한 데이터
                      '평일운영시작시각', # 불필요한 데이터
                      '평일운영종료시각', # 불필요한 데이터
                      '토요일운영시작시각', # 불필요한 데이터
                      '토요일운영종료시각', # 불필요한 데이터
                      '공휴일운영시작시각', # 불필요한 데이터
                      '공휴일운영종료시각', # 불필요한 데이터
                      '요금정보', # 불필요한 데이터
                      '주차기본시간', # 불필요한 데이터
                      '주차기본요금', # 불필요한 데이터
                      '데이터기준일자', # 불필요한 데이터
                      '관리기관명', # 불필요한 데이터
                      ], axis=1)
print(df_remove.shape)
# Out:
# (870, 7)

# %%
df_remove.columns
# Out:
# Index(['주차장명', '주차장유형', '소재지도로명주소', '소재지지번주소', '위도', '경도', '제공기관명'], dtype='object')

# %%
df_remove
# Out:
#                주차장명 주차장유형                  소재지도로명주소  \
# 0          탄방동탄방역주변    노상       대전광역시 서구 계룡로553번길38
# 1         유성IC만남의광장    노상  대전광역시 유성구 월드컵대로 31 (장대동)
# 2       세천7 공한지 주차장    노외                       NaN
# 3       세천8 공한지 주차장    노외                       NaN
# 4          신도시장 주차장    노외         대전광역시 동구 비래서로42번길
# ..              ...   ...                       ...
# 865        로히트~가을햇살    노상        대전광역시 유성구 농대로2번길 9
# 866        문화2동제2노상    노상      대전광역시 중구 당디로36번길 113
# 867        문화2동제3노상    노상          대전광역시 중구 문화로 170
# 868  어은로58번길(카이스트옆)    노상         대전광역시 유성구 어은로58번길
# 869          이현동주차장    노외  대전광역시 대덕구 대청호수로1326번길 75
#
#                         소재지지번주소         위도          경도      제공기관명
# 0               대전광역시 서구 탄방동667        NaN         NaN      대전광역시
# 1          대전광역시 유성구 장대동 240-43        NaN         NaN      대전광역시
# 2            대전광역시 동구 세천동 47-11        NaN         NaN      대전광역시
# 3             대전광역시 동구 세천동 76-1        NaN         NaN      대전광역시
# ...

# %%
df_remove.info()
# 15.7+MB -> 2.5+ MB
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   주차장명      870 non-null    object
#  1   주차장유형     870 non-null    object
#  2   소재지도로명주소  707 non-null    object
#  3   소재지지번주소   868 non-null    object
#  4   위도        489 non-null    float64
#  5   경도        488 non-null    float64
#  6   제공기관명     870 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 47.7+ KB

# %%
df_remove.columns
# Out:
# Index(['주차장명', '주차장유형', '소재지도로명주소', '소재지지번주소', '위도', '경도', '제공기관명'], dtype='object')

# %%
df_remove
# Out:
#                주차장명 주차장유형                  소재지도로명주소  \
# 0          탄방동탄방역주변    노상       대전광역시 서구 계룡로553번길38
# 1         유성IC만남의광장    노상  대전광역시 유성구 월드컵대로 31 (장대동)
# 2       세천7 공한지 주차장    노외                       NaN
# 3       세천8 공한지 주차장    노외                       NaN
# 4          신도시장 주차장    노외         대전광역시 동구 비래서로42번길
# ..              ...   ...                       ...
# 865        로히트~가을햇살    노상        대전광역시 유성구 농대로2번길 9
# 866        문화2동제2노상    노상      대전광역시 중구 당디로36번길 113
# 867        문화2동제3노상    노상          대전광역시 중구 문화로 170
# 868  어은로58번길(카이스트옆)    노상         대전광역시 유성구 어은로58번길
# 869          이현동주차장    노외  대전광역시 대덕구 대청호수로1326번길 75
#
#                         소재지지번주소         위도          경도      제공기관명
# 0               대전광역시 서구 탄방동667        NaN         NaN      대전광역시
# 1          대전광역시 유성구 장대동 240-43        NaN         NaN      대전광역시
# 2            대전광역시 동구 세천동 47-11        NaN         NaN      대전광역시
# 3             대전광역시 동구 세천동 76-1        NaN         NaN      대전광역시
# ...

# %%
addrs = df_remove['소재지도로명주소']
addrs
# Out:
# 0           대전광역시 서구 계룡로553번길38
# 1      대전광역시 유성구 월드컵대로 31 (장대동)
# 2                           NaN
# 3                           NaN
# 4             대전광역시 동구 비래서로42번길
#                  ...
# 865          대전광역시 유성구 농대로2번길 9
# 866        대전광역시 중구 당디로36번길 113
# 867            대전광역시 중구 문화로 170
# 868           대전광역시 유성구 어은로58번길
# 869    대전광역시 대덕구 대청호수로1326번길 75
# Name: 소재지도로명주소, Length: 870, dtype: object

# %%
df_list = df_remove['소재지도로명주소'].values.tolist()

# %%
import requests

# %%
import json

# %%
rest_api_key = "0d0709db6751827512ffd587663e2757"

# %%
class KakaoLocalAPI:
    """
    Kakao Local API Controller
    """
    def __init__(self, rest_api_key):
        """
        Rest API key 초기화 및 기능 별 url 설정
        """
        
        # REST API key 설정
        self.rest_api_key = rest_api_key
        self.headers = {"Authorization": "KakaoAK {}".format(rest_api_key)}
        
        # 01 주소검색
        self.URL_01 = "https://dapi.kakao.com/v2/local/search/address.json"
        
    def search_address(self, query, analyze_type = None, page = None, size = None):
        """
        01 주소 검색
        """
        params = {"query": f"{query}"}
    
        if analyze_type != None:
            params["analyze_type"]=f"{analyze_type}"
    
        elif page != None:
            params['page'] = f"{page}"
    
        elif size != None:
            params['size'] = f"{size}"
    
        res = requests.get(self.URL_01, headers = self.headers, params = params)
        document = json.loads(res.text)
    
        return document

# %%
df_list
# for 문을 만들어서 리스트를 돌면서 전부 출력 가능하게 만들어라
# Out:
# ['대전광역시 서구 계룡로553번길38',
#  '대전광역시 유성구 월드컵대로 31 (장대동)',
#  nan,
#  nan,
#  '대전광역시 동구 비래서로42번길',
#  nan,
#  nan,
#  '대전광역시 동구 대전로 779번길 8',
#  nan,
#  '대전광역시 동구 새울로 91번길',
#  '대전광역시 동구 동서대로',
#  '대전광역시 동구 동서대로 1659',
#  '대전광역시 동구 계족로 517번길',
#  '대전광역시 동구 대전로 679',
#  '대전광역시 동구 대전천동로',
#  '대전광역시 동구 역전3길',
#  '대전광역시 동구 중앙로 200번길 70',
#  '대전광역시 동구 대전로 791번길',
#  nan,
#  '대전광역시 동구 동부로 73',
#  '대전광역시 동구 태전로 27',
#  '대전광역시 동구 대동천좌안, 대동천우안',
#  '대전광역시 동구 대전천동로',
#  '대전광역시 동구 대동천좌안, 대동천우안',
#  nan,
#  nan,
#  '대전광역시 동구 선화로 192번길',
#  '대전광역시 동구 선화로192번길',
#  '대전광역시 동구 세천공원로35번길',
#  '대전광역시 동구 세천로',
#  nan,
#  nan,
#  '대전광역시 중구 보문로48번길 13',
#  '대전광역시 중구 대종로 315번길 34-17',
#  '대전광역시 중구 뿌리공원로 47',
#  '대전광역시 중구 보문산공원로497번길 81-7',
#  '대전광역시 중구 보문로47번길 146',
#  '대전광역시 중구 보문산공원로 497번길 72',
#  nan,
#  nan,
#  nan,
#  '대전광역시 중구 보문산로171번길 34',
#  nan,
#  '대전광역시 중구 동서대로1352번길 29',
#  '대전광역시 중구 수침로55번길 56',
#  '대전광역시 중구 충무로74번길 10',
#  '대전광역시 중구 보문산공원로 505',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
# ...

# %%
kakao = KakaoLocalAPI(rest_api_key)

# %%
result_01 = kakao.search_address(query)
result_01
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# ...
